# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
# %matplotlib inline

# %%
mnist=tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,Conv2D,MaxPooling2D

# %%
model=Sequential()

# %%
model.add(Flatten(input_shape=(28,28)))

# %%
model.add(Dense(128,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 2s 693us/step - loss: 0.2618 - accuracy: 0.9241
# Epoch 2/3
# 1875/1875 [==============================] - 1s 677us/step - loss: 0.1069 - accuracy: 0.9675
# Epoch 3/3
# 1875/1875 [==============================] - 1s 673us/step - loss: 0.0743 - accuracy: 0.9759

# %%
loss,accuracy=model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 503us/step - loss: 0.0946 - accuracy: 0.9704

# %%
print(loss)
# Out:
# 0.0945696011185646

# %%
print(accuracy)
# Out:
# 0.9703999757766724

# %%
predictions=model.predict(x_test)

# %%
print(predictions)
# Out:
# [[1.0690967e-07 4.5181192e-08 1.6049542e-04 ... 9.9981064e-01
#   4.1756856e-08 9.0672211e-07]
#  [7.1427757e-09 8.3426849e-06 9.9998820e-01 ... 3.0238864e-10
#   1.7940437e-08 5.3010482e-13]
#  [3.4167183e-06 9.9911648e-01 8.8181587e-06 ... 2.0503606e-04
#   4.0923903e-04 1.1483282e-05]
#  ...
#  [1.9509528e-08 9.2595559e-07 7.6702065e-07 ... 6.1525934e-04
#   2.7145620e-06 1.5942237e-04]
#  [6.6104178e-07 2.7142505e-07 7.6746420e-07 ... 1.9515805e-06
#   1.2534276e-04 1.8042181e-08]
#  [1.6238640e-07 3.7590322e-08 1.7793687e-06 ... 1.5367853e-09
#   3.1528231e-08 5.9164673e-10]]

# %%
print(np.argmax(predictions[5]))
# Out:
# 1

# %%
plt.imshow(x_test[5])

# %%
x_test[5].shape
# Out:
# (28, 28)

# %%
img=cv2.imread("3 image.png")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (414, 311, 3)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (414, 311)

# %%
resized=cv2.resize(gray,(28,28),interpolation=cv2.INTER_AREA)

# %%
resized.shape
# Out:
# (28, 28)

# %%
newing=tf.keras.utils.normalize(resized,axis=1)

# %%
newing=np.array(newing).reshape(-1,28,28,1)

# %%
newing.shape
# Out:
# (1, 28, 28, 1)

# %%
pred=model.predict(newing)

# %%
print(np.argmax(pred))
# Out:
# 3

# %%
img1=cv2.imread("3 image.png")
plt.imshow(img1)

# %%
img1.shape
# Out:
# (414, 311, 3)

# %%
gray1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
gray1.shape
# Out:
# (414, 311)

# %%
resized1=cv2.resize(gray1,(28,28),interpolation=cv2.INTER_AREA)
resized1.shape
# Out:
# (28, 28)

# %%
newing1=tf.keras.utils.normalize(resized1,axis=1)
newing1=np.array(newing1).reshape(-1,28,28,1)
newing1.shape
# Out:
# (1, 28, 28, 1)

# %%
pred1=model.predict(newing1)

# %%
print(np.argmax(pred1))
# Out:
# 3
